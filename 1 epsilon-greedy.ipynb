# %% [markdown]
# # Task 1
#
# We want to implement the epsioln greedy algorithm. The purpose of the algorithm is to balance exploration wiht exploitation.
#
# Epsilon greedy will pick the best option except for epssilon times every 100 trials.
#
# In this taks we want to explore a matrix where a row represent all the posible rewards that we can receive based on the state we are at the moment.

# %%
import numpy as np

epsilon = 0.5


def epsilon_greedy(s, q, epsilon=0.2):
    a = np.argmax(q[s, :])
    if np.random.rand() < epsilon:
        a = np.random.randint(q.shape[1])
    return a

# Matrix that we want to explore using epsilon greedy
q = np.array([[0, 1, 3, 4],
              [0, 7, 5, 5],
              [4, 1, 1, 4]])

# Each states correspond to a row in the q-matrix
states = range(q.shape[0])

for state in states:
    e_greedy_action = (epsilon_greedy(state, q))
    print(
        f'The epsioln-greedy action was: {e_greedy_action} while the best was: {np.argmax(q[state, :])}'
    )
# Out:
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 0 while the best was: 1
# The epsioln-greedy action was: 1 while the best was: 0

# %% [markdown]
# # Task 2
#
# In a Reinforcement learning algoritm we want to decrease epsiol as we are gaining more knowledg of the algorithm. We want to implement a simple method to accomplish that.
#
# After compliting the task please try different values for epsilon and epsilon_decay.

# %%
epsilon = 0.5
epsilon_decay = 0.9
error_history = []
epsilon_history = []

for i in range(100):
    total_error = 0
    epsilon_history.append(epsilon)
    epsilon = epsilon * epsilon_decay
    for state in states:
        e_greedy_action = (epsilon_greedy(state, q, epsilon))
        total_error = total_error + q[state, np.argmax(q[state, :])] - q[state, e_greedy_action]
        print(
            f'The epsioln-greedy action was: {e_greedy_action} while the best was: {np.argmax(q[state, :])}'
        )
    error_history.append(total_error)
# Out:
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 2 while the best was: 1
# The epsioln-greedy action was: 0 while the best was: 0
# The epsioln-greedy action was: 2 while the best was: 3
# The epsioln-greedy action was: 1 while the best was: 1
# The epsioln-greedy action was: 0 while the best was: 0
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 1 while the best was: 1
# The epsioln-greedy action was: 0 while the best was: 0
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 1 while the best was: 1
# The epsioln-greedy action was: 0 while the best was: 0
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 1 while the best was: 1
# The epsioln-greedy action was: 0 while the best was: 0
# The epsioln-greedy action was: 3 while the best was: 3
# The epsioln-greedy action was: 2 while the best was: 1
# ...

# %%
# %matplotlib inline
import pandas as pd
error = pd.DataFrame({'Error': error_history, 'Epsilon': epsilon_history})
error.plot()
